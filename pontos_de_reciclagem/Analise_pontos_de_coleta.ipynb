# %% [markdown]
# # Importando bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Lendo arquivos e checando head e info

# %%
dados_gabriel = pd.read_csv(r'C:\Users\rubir\MyProjects\arquivos_gabriel.csv')
dados_gabriel.head()
# Out:
#   estado     cidade                 local                            endereço  \
# 0     SP  GUARULHOS                   s/n  Rua João Bernardo de Medeiros, 800
# 1     SP  GUARULHOS        Vila Sant Anna   Rua Soldado Estanislau Wojcik, 26
# 2     SP  GUARULHOS         Vila Zamataro   Alameda Josefina L. Zamataro, 233
# 3     SP  GUARULHOS  Jardim Flor do Campo  Rua Guilherme Lino dos Santos, 349
# 4     SP  GUARULHOS           Vila Galvão                   Rua Ipiranga, 543
#
#          bairro                                   tipo_de_material  \
# 0     Bom Clima  Coleta seletiva, obras e materiais, líquidos, ...
# 1        Macedo  Coleta seletiva, obras e materiais, líquidos, ...
# 2  Ponte Grande  Coleta seletiva, obras e materiais, líquidos, ...
# 3   Vila Barros  Coleta seletiva, obras e materiais, líquidos, ...
# 4   Vila Galvão  Coleta seletiva, obras e materiais, líquidos, ...
#
#   horário_seg-sex horário_sab-dom      tipo
# 0        8h15-16h      8h15-15h30  ecoponto
# 1        8h15-16h      8h15-15h30  ecoponto
# 2        8h15-16h      8h15-15h30  ecoponto
# 3        8h15-16h      8h15-15h30  ecoponto
# 4        8h15-16h      8h15-15h30  ecoponto

# %%
dados_gabriel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   estado            369 non-null    object
#  1   cidade            369 non-null    object
#  2   local             369 non-null    object
#  3   endereço          369 non-null    object
#  4   bairro            369 non-null    object
#  5   tipo_de_material  369 non-null    object
#  6   horário_seg-sex   369 non-null    object
#  7   horário_sab-dom   369 non-null    object
#  8   tipo              369 non-null    object
# dtypes: object(9)
# memory usage: 26.1+ KB

# %%
dados_luiz = pd.read_csv(r'C:\Users\rubir\MyProjects\arquivos_luiz.csv', 
                         encoding='latin1', 
                         on_bad_lines='skip',
                         sep =';')

dados_luiz.head()
# Out:
#   estado       cidade                                local  \
# 0     SP  São Vicente                 Assai Atacadista S/a
# 1     SP  São Vicente  Associação Comercial De São Vicente
# 2     SP  São Vicente                         Atacadão S.a
# 3     SP  São Vicente                   Baratão Das Tintas
# 4     SP  São Vicente             C & C - Loja São Vicente
#
#                 endereço         bairro        cep  \
# 0   Antonio Emerick, 291         centro  00000-000
# 1    Jacob Emerick, 1235         centro  00000-000
# 2         Ponte Nova, 12  jd. nosso lar  00000-000
# 3  Antonio Emerick, 1445   Vila cascata  00000-000
# 4  Antonio Emerick, 1424         centro  00000-000
#
#               tipo de material horario_seg_sex horario_sab_dom     tipo  \
# 0                  Eletrônicos  Não disponível  Não disponível  Empresa
# 1                  Eletrônicos  Não disponível  Não disponível  Empresa
# 2                  Eletrônicos  Não disponível  Não disponível  Empresa
# 3              Coleta seletiva  Não disponível  Não disponível  Empresa
# 4  Coleta seletiva,Eletrônicos  Não disponível  Não disponível  Empresa
#
#    Unnamed: 10 Unnamed: 11  Unnamed: 12  Unnamed: 13
# 0          NaN         NaN          NaN          NaN
# 1          NaN         NaN          NaN          NaN
# 2          NaN         NaN          NaN          NaN
# 3          NaN         NaN          NaN          NaN
# 4          NaN         NaN          NaN          NaN

# %%
dados_luiz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1802 entries, 0 to 1801
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   estado            1802 non-null   object
#  1   cidade            1802 non-null   object
#  2   local             1802 non-null   object
#  3   endereço          1802 non-null   object
#  4   bairro            1802 non-null   object
#  5   cep               1801 non-null   object
#  6   tipo de material  1802 non-null   object
#  7   horario_seg_sex   1802 non-null   object
#  8   horario_sab_dom   1801 non-null   object
#  9   tipo              1802 non-null   object
#  10  Unnamed: 10       0 non-null      float64
#  11  Unnamed: 11       131 non-null    object
#  12  Unnamed: 12       0 non-null      float64
#  13  Unnamed: 13       0 non-null      float64
# dtypes: float64(3), object(11)
# memory usage: 197.2+ KB

# %%
dados_patricia = pd.read_csv(r'C:\Users\rubir\MyProjects\arquivos_patricia.csv')
dados_patricia.head()
# Out:
#   estado     cidade                        local                   endereço  \
# 0     SP  São Paulo               Hirota - Mooca          Rua Teresina, 319
# 1     SP  São Paulo               Super Saudável   Avenida São Gualter, 931
# 2     SP  São Paulo              COOP Industrial   Avenida Industrial, 2001
# 3     SP  São Paulo          Hirota - Campo Belo  Rua Vieira de Morais, 263
# 4     SP  São Paulo  Emporium São Paulo - Jurema        Avenida Jurema, 271
#
#               bairro        cep  tipo_de_material horario_seg_sex  \
# 0      Vila Bertioga  03185-010  Cápsulas de café             NaN
# 1  Alto de Pinheiros  05455-001  Cápsulas de café             NaN
# 2          Campestre  09080-511  Cápsulas de café             NaN
# 3         Campo Belo  04617-010  Cápsulas de café             NaN
# 4       Indianópolis  04087-000  Cápsulas de café             NaN
#
#   horario_sab_dom           tipo
# 0             NaN  Três Corações
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN

# %%
dados_patricia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   estado            852 non-null    object
#  1   cidade            849 non-null    object
#  2   local             647 non-null    object
#  3   endereço          852 non-null    object
#  4   bairro            690 non-null    object
#  5   cep               410 non-null    object
#  6   tipo_de_material  852 non-null    object
#  7   horario_seg_sex   470 non-null    object
#  8   horario_sab_dom   470 non-null    object
#  9   tipo              514 non-null    object
# dtypes: object(10)
# memory usage: 66.7+ KB

# %%
def verificar_dados(df, nome_df):
    valores_ausentes = df.isnull().sum().sum()
    valores_duplicados = df.duplicated().sum()
    return f"Existem {valores_ausentes} valores ausentes em {nome_df}\nExistem {valores_duplicados} valores duplicados em {nome_df}"

problemas_gabriel = verificar_dados(dados_gabriel, "dados_gabriel")
problemas_luiz = verificar_dados(dados_luiz, "dados_luiz")
problemas_patricia = verificar_dados(dados_patricia, "dados_patricia")

print(problemas_gabriel)
print(problemas_luiz)
print(problemas_patricia)
# Out:
# Existem 0 valores ausentes em dados_gabriel
# Existem 1 valores duplicados em dados_gabriel
# Existem 7079 valores ausentes em dados_luiz
# Existem 0 valores duplicados em dados_luiz
# Existem 1914 valores ausentes em dados_patricia
# Existem 5 valores duplicados em dados_patricia

# %% [markdown]
# # Pré-processamento dos dados

# %% [markdown]
# # dados_gabriel

# %% [markdown]
# Primeiro alterando alguns detalhes em dados_gabriel:
#
#     - Vou padronizar a primeira letra maiúscula e as outras minusculas.
#     - Vou adicionar uma coluna CEP com valores 00000-000 pois eu não encontrei diversos ceps e não coletei os de farmácias
#     - Existe um valor duplicado, vou checa-lo
#     - Vou mudar o nome das colunas de "horário_seg_sex" e "horário_sab_dom" e remover o "á"

# %%
dados_gabriel['cidade'] = dados_gabriel['cidade'].str.title()

dados_gabriel['cidade'].value_counts()
# Out:
# cidade
# São Paulo                140
# Guarulhos                 45
# Santo André               31
# Campinas                  30
# Ribeirão Preto            27
# São José Dos Campos       22
# Santos                    15
# São Bernardo Do Campo     13
# Piracicaba                12
# Sorocaba                  11
# São José Do Rio Preto     10
# Osasco                     8
# Mauá                       5
# Name: count, dtype: int64

# %%
dados_gabriel['tipo_de_material'].value_counts()
# Out:
# tipo_de_material
# medicamentos                                                           240
# Coleta seletiva, obras e materiais                                      48
# Coleta seletiva, obras e materiais, líquidos, borracha                  33
# coleta seletiva, obras e materiais, eletrônicos, líquidos, borracha     15
# Coleta seletiva, obras e materiais, borracha e eletrônicos              14
# Coleta seletiva, obras e materiais, eletrônicos                         12
# Coleta seletiva, eletrônicos, líquidos, obras e materiais                5
# Borracha                                                                 1
# Eletrônicos                                                              1
# Name: count, dtype: int64

# %%
dados_gabriel['tipo_de_material'] = dados_gabriel['tipo_de_material'].str.title()
dados_gabriel['tipo_de_material'].value_counts()
# Out:
# tipo_de_material
# Medicamentos                                                           240
# Coleta Seletiva, Obras E Materiais                                      48
# Coleta Seletiva, Obras E Materiais, Líquidos, Borracha                  33
# Coleta Seletiva, Obras E Materiais, Eletrônicos, Líquidos, Borracha     15
# Coleta Seletiva, Obras E Materiais, Borracha E Eletrônicos              14
# Coleta Seletiva, Obras E Materiais, Eletrônicos                         12
# Coleta Seletiva, Eletrônicos, Líquidos, Obras E Materiais                5
# Borracha                                                                 1
# Eletrônicos                                                              1
# Name: count, dtype: int64

# %%
ceps = ['00000-000']*369
dados_gabriel['cep'] = ceps
coluna_cep = dados_gabriel.pop('cep')
dados_gabriel.insert(5, 'cep', coluna_cep)
dados_gabriel.head()
# Out:
#   estado     cidade                 local                            endereço  \
# 0     SP  Guarulhos                   s/n  Rua João Bernardo de Medeiros, 800
# 1     SP  Guarulhos        Vila Sant Anna   Rua Soldado Estanislau Wojcik, 26
# 2     SP  Guarulhos         Vila Zamataro   Alameda Josefina L. Zamataro, 233
# 3     SP  Guarulhos  Jardim Flor do Campo  Rua Guilherme Lino dos Santos, 349
# 4     SP  Guarulhos           Vila Galvão                   Rua Ipiranga, 543
#
#          bairro        cep                                   tipo_de_material  \
# 0     Bom Clima  00000-000  Coleta Seletiva, Obras E Materiais, Líquidos, ...
# 1        Macedo  00000-000  Coleta Seletiva, Obras E Materiais, Líquidos, ...
# 2  Ponte Grande  00000-000  Coleta Seletiva, Obras E Materiais, Líquidos, ...
# 3   Vila Barros  00000-000  Coleta Seletiva, Obras E Materiais, Líquidos, ...
# 4   Vila Galvão  00000-000  Coleta Seletiva, Obras E Materiais, Líquidos, ...
#
#   horário_seg-sex horário_sab-dom      tipo
# 0        8h15-16h      8h15-15h30  ecoponto
# 1        8h15-16h      8h15-15h30  ecoponto
# 2        8h15-16h      8h15-15h30  ecoponto
# 3        8h15-16h      8h15-15h30  ecoponto
# 4        8h15-16h      8h15-15h30  ecoponto

# %%
dados_gabriel[dados_gabriel.duplicated(keep=False)]
# Out:
#     estado          cidade      local         endereço        bairro  \
# 317     SP  Ribeirão Preto  Drogaraia  Rua Chile, 1595  Jardim Irajá
# 320     SP  Ribeirão Preto  Drogaraia  Rua Chile, 1595  Jardim Irajá
#
#            cep tipo_de_material horário_seg-sex horário_sab-dom     tipo
# 317  00000-000     Medicamentos          7h-23h          7h-23h  privado
# 320  00000-000     Medicamentos          7h-23h          7h-23h  privado

# %%
dados_gabriel = dados_gabriel.drop_duplicates()
dados_gabriel.duplicated().sum()
# Out:
# 0

# %%
dados_gabriel.rename(columns={'horário_seg-sex': 'horario_seg_sex', 'horário_sab-dom': 'horario_sab_dom'}, inplace=True)
dados_gabriel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 368 entries, 0 to 368
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   estado            368 non-null    object
#  1   cidade            368 non-null    object
#  2   local             368 non-null    object
#  3   endereço          368 non-null    object
#  4   bairro            368 non-null    object
#  5   cep               368 non-null    object
#  6   tipo_de_material  368 non-null    object
#  7   horario_seg_sex   368 non-null    object
#  8   horario_sab_dom   368 non-null    object
#  9   tipo              368 non-null    object
# dtypes: object(10)
# memory usage: 31.6+ KB

# %% [markdown]
# Fiz todas alterações necessárias em dados_gabriel. Agora, para dados_luiz

# %% [markdown]
# # dados_luiz

# %%
dados_luiz.head()
# Out:
#   estado       cidade                                local  \
# 0     SP  São Vicente                 Assai Atacadista S/a
# 1     SP  São Vicente  Associação Comercial De São Vicente
# 2     SP  São Vicente                         Atacadão S.a
# 3     SP  São Vicente                   Baratão Das Tintas
# 4     SP  São Vicente             C & C - Loja São Vicente
#
#                 endereço         bairro        cep  \
# 0   Antonio Emerick, 291         centro  00000-000
# 1    Jacob Emerick, 1235         centro  00000-000
# 2         Ponte Nova, 12  jd. nosso lar  00000-000
# 3  Antonio Emerick, 1445   Vila cascata  00000-000
# 4  Antonio Emerick, 1424         centro  00000-000
#
#               tipo de material horario_seg_sex horario_sab_dom     tipo  \
# 0                  Eletrônicos  Não disponível  Não disponível  Empresa
# 1                  Eletrônicos  Não disponível  Não disponível  Empresa
# 2                  Eletrônicos  Não disponível  Não disponível  Empresa
# 3              Coleta seletiva  Não disponível  Não disponível  Empresa
# 4  Coleta seletiva,Eletrônicos  Não disponível  Não disponível  Empresa
#
#    Unnamed: 10 Unnamed: 11  Unnamed: 12  Unnamed: 13
# 0          NaN         NaN          NaN          NaN
# 1          NaN         NaN          NaN          NaN
# 2          NaN         NaN          NaN          NaN
# 3          NaN         NaN          NaN          NaN
# 4          NaN         NaN          NaN          NaN

# %%
dados_luiz.isna().sum()
# Out:
# estado                 0
# cidade                 0
# local                  0
# endereço               0
# bairro                 0
# cep                    1
# tipo de material       0
# horario_seg_sex        0
# horario_sab_dom        1
# tipo                   0
# Unnamed: 10         1802
# Unnamed: 11         1671
# Unnamed: 12         1802
# Unnamed: 13         1802
# dtype: int64

# %% [markdown]
# Algumas alterações:
#
#     - Vou remover as colunas unnamed
#     - Vou checar os valores ausentes em "horario_sab_dom" e "cep"
#     - Vou adicionar "_" na coluna "tipo de material"
#     - Por enquanto não vou fazer alterações, mas os valores de CEP estão inconsistentes.
#     - Vamos pensar em algum modo de padronizar a coluna "tipo"

# %%
dados_luiz = dados_luiz.iloc[:, :10]
dados_luiz.rename(columns={'tipo de material': 'tipo_de_material'}, inplace=True)
dados_luiz.head()
# Out:
#   estado       cidade                                local  \
# 0     SP  São Vicente                 Assai Atacadista S/a
# 1     SP  São Vicente  Associação Comercial De São Vicente
# 2     SP  São Vicente                         Atacadão S.a
# 3     SP  São Vicente                   Baratão Das Tintas
# 4     SP  São Vicente             C & C - Loja São Vicente
#
#                 endereço         bairro        cep  \
# 0   Antonio Emerick, 291         centro  00000-000
# 1    Jacob Emerick, 1235         centro  00000-000
# 2         Ponte Nova, 12  jd. nosso lar  00000-000
# 3  Antonio Emerick, 1445   Vila cascata  00000-000
# 4  Antonio Emerick, 1424         centro  00000-000
#
#               tipo_de_material horario_seg_sex horario_sab_dom     tipo
# 0                  Eletrônicos  Não disponível  Não disponível  Empresa
# 1                  Eletrônicos  Não disponível  Não disponível  Empresa
# 2                  Eletrônicos  Não disponível  Não disponível  Empresa
# 3              Coleta seletiva  Não disponível  Não disponível  Empresa
# 4  Coleta seletiva,Eletrônicos  Não disponível  Não disponível  Empresa

# %%
dados_luiz[dados_luiz['cep'].isna()]
# Out:
#      estado   cidade      local                           endereço   bairro  \
# 1457     RS  Pelotas  Carrefour  Av. Presidente João Goulart, 6161  Fragata
#
#       cep tipo_de_material horario_seg_sex horario_sab_dom       tipo
# 1457  NaN      Eletrônicos    8:00 - 21:00    8:00 - 21:00  Carrefour

# %%
dados_luiz['cep'] = dados_luiz['cep'].fillna('00000-000')
dados_luiz[dados_luiz['cep'].isna()]
# Out:
# Empty DataFrame
# Columns: [estado, cidade, local, endereço, bairro, cep, tipo_de_material, horario_seg_sex, horario_sab_dom, tipo]
# Index: []

# %%
dados_luiz[dados_luiz['horario_sab_dom'].isna()]
# Out:
#      estado    cidade             local               endereço  \
# 1111     SP  Campinas  Reciclagem Prime  Rua Eduardo Lane, 200
#
#               bairro        cep           tipo_de_material horario_seg_sex  \
# 1111  Jardim Proença  13026-430  Coleta seletiva, Liquidos    8:00 - 18:00
#
#      horario_sab_dom     tipo
# 1111             NaN  Empresa

# %%
dados_luiz['horario_sab_dom'] = dados_luiz['horario_sab_dom'].fillna('Não disponível')
dados_luiz[dados_luiz['horario_sab_dom'].isna()]
# Out:
# Empty DataFrame
# Columns: [estado, cidade, local, endereço, bairro, cep, tipo_de_material, horario_seg_sex, horario_sab_dom, tipo]
# Index: []

# %% [markdown]
# # dados_patricia

# %%
dados_patricia.head()
# Out:
#   estado     cidade                        local                   endereço  \
# 0     SP  São Paulo               Hirota - Mooca          Rua Teresina, 319
# 1     SP  São Paulo               Super Saudável   Avenida São Gualter, 931
# 2     SP  São Paulo              COOP Industrial   Avenida Industrial, 2001
# 3     SP  São Paulo          Hirota - Campo Belo  Rua Vieira de Morais, 263
# 4     SP  São Paulo  Emporium São Paulo - Jurema        Avenida Jurema, 271
#
#               bairro        cep  tipo_de_material horario_seg_sex  \
# 0      Vila Bertioga  03185-010  Cápsulas de café             NaN
# 1  Alto de Pinheiros  05455-001  Cápsulas de café             NaN
# 2          Campestre  09080-511  Cápsulas de café             NaN
# 3         Campo Belo  04617-010  Cápsulas de café             NaN
# 4       Indianópolis  04087-000  Cápsulas de café             NaN
#
#   horario_sab_dom           tipo
# 0             NaN  Três Corações
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN

# %%
dados_patricia.isna().sum()
# Out:
# estado                0
# cidade                3
# local               205
# endereço              0
# bairro              162
# cep                 442
# tipo_de_material      0
# horario_seg_sex     382
# horario_sab_dom     382
# tipo                338
# dtype: int64

# %% [markdown]
# Agora para o dataset dados_patricia.
#
#     - Vou verificar os valores ausentes
#     - Vou checar os dados duplicados
#     - Checar a coluna tipo para padronização
#     - Realizar mudanças em tipo_de_material
#     - Converter valores ausentes na coluna de horário para "Não disponível"

# %%
dados_patricia[dados_patricia['cidade'].isna()].head()
# Out:
#     estado cidade                           local  \
# 110     SP    NaN             SHOPPING ARICANDUVA
# 126     SP    NaN  SHOPPING CENTER\nFERNANDÓPOLIS
# 172     SP    NaN       PARK SHOPPING SÃO CAETANO
#
#                                      endereço             bairro        cep  \
# 110  Avenida Aricanduva, 5555 - Loja Âncora 1  Jardim Aricanduva  03527-000
# 126         Avenida LITERIO GRECCO NÚMERO 600                NaN        NaN
# 172    Alameda Terracota, 545, loja 1007/2007           Cerâmica  09531-190
#
#     tipo_de_material horario_seg_sex horario_sab_dom tipo
# 110           Roupas             NaN             NaN  NaN
# 126           Roupas             NaN             NaN  NaN
# 172           Roupas             NaN             NaN  NaN

# %%
indices_cidades_ausentes = dados_patricia[dados_patricia['cidade'].isnull()].index
dados_patricia.loc[indices_cidades_ausentes[0], 'cidade'] = 'São Paulo'
dados_patricia.loc[indices_cidades_ausentes[1], 'cidade'] = 'Fernandópolis'
dados_patricia.loc[indices_cidades_ausentes[2], 'cidade'] = 'São Paulo'

dados_patricia[dados_patricia['cidade'].isna()].head()
# Out:
# Empty DataFrame
# Columns: [estado, cidade, local, endereço, bairro, cep, tipo_de_material, horario_seg_sex, horario_sab_dom, tipo]
# Index: []

# %%
dados_patricia[dados_patricia['local'].isna()].head()
# Out:
#     estado     cidade local  \
# 380     SP  São Paulo   NaN
# 381     SP  São Paulo   NaN
# 382     SP  São Paulo   NaN
# 383     SP  São Paulo   NaN
# 384     SP  São Paulo   NaN
#
#                                               endereço          bairro  \
# 380                                  RUA AURÉLIA, 1973     Vila Romana
# 381                             Rua James Holland, 668      Guaianases
# 382  Avenida Raimundo Pereira de Magalhães - de 110...  Vila Paranagua
# 383  Avenida das Nações Unidas - de 12997 a 17279 -...  Freguesia do Ó
# 384              Avenida Senador Teotônio Vilela, 1324      Guaianases
#
#            cep  tipo_de_material horario_seg_sex horario_sab_dom  \
# 380        NaN  Cápsulas de café             NaN             NaN
# 381  01138-000   Lixo eletrônico    07:00 -18:00    07:00 -14:00
# 382  05145-200   Lixo eletrônico    07:00 -18:00    07:00 -14:00
# 383  04795-100   Lixo eletrônico    07:00 -18:00    07:00 -14:00
# 384  04801-000   Lixo eletrônico    07:00 -18:00    07:00 -14:00
#
#               tipo
# 380  Três Corações
# 381  Green Eletron
# 382  Green Eletron
# 383  Green Eletron
# 384  Green Eletron

# %%
dados_patricia['local'] = dados_patricia['local'].fillna('Não informado')
dados_patricia[dados_patricia['local'].isna()]
# Out:
# Empty DataFrame
# Columns: [estado, cidade, local, endereço, bairro, cep, tipo_de_material, horario_seg_sex, horario_sab_dom, tipo]
# Index: []

# %%
dados_patricia[dados_patricia['bairro'].isna()].head()
# Out:
#    estado                 cidade                           local  \
# 11     SP  Ferraz de Vasconcelos  Ecoponto Ferraz de Vasconcelos
# 62     SP          Guaratinguetá           BURITI SHOPPING GUARÁ
# 63     SP               Campinas               CENTRO - CAMPINAS
# 64     SP               Campinas        CAMPINAS SHOPPING CENTER
# 65     SP               Campinas     SHOPPING IGUATEMI\nCAMPINAS
#
#                                              endereço bairro        cep  \
# 11         Av. dos Multirantes, s/n Jd, Rua Itajuibe,    NaN  08540-540
# 62  Avenida Juscelino Kubitschek de Oliveira, 351,...    NaN        NaN
# 63       Rua 13 de Maio, 520 - Centro - Campinas - SP    NaN        NaN
# 64  Rua Jacy Teixeira de Camargo, nº 940 – ancora ...    NaN        NaN
# 65  Av. Iguatemi, 777 - Loja "E" - Vila Brandina -...    NaN        NaN
#
#                   tipo_de_material horario_seg_sex horario_sab_dom tipo
# 11  Papel, plástico, vidro e metal             NaN             NaN  NaN
# 62                 Lixo eletrônico             NaN             NaN  NaN
# 63                 Lixo eletrônico             NaN             NaN  NaN
# 64                 Lixo eletrônico             NaN             NaN  NaN
# 65                 Lixo eletrônico             NaN             NaN  NaN

# %%
dados_patricia['bairro'] = dados_patricia['bairro'].fillna('Não informado')
dados_patricia[dados_patricia['bairro'].isna()]
# Out:
# Empty DataFrame
# Columns: [estado, cidade, local, endereço, bairro, cep, tipo_de_material, horario_seg_sex, horario_sab_dom, tipo]
# Index: []

# %%
dados_patricia[dados_patricia['cep'].isna()].head()
# Out:
#    estado     cidade                   local  \
# 16     SP  São Paulo  CENTRAL PLAZA SHOPPING
# 17     SP  São Paulo    SHOPPING CAMPO LIMPO
# 18     SP  São Paulo     SHOPPING IBIRAPUERA
# 19     SP  São Paulo     SHOPPING INTERLAGOS
# 20     SP  São Paulo     SHOPPING JARDIM SUL
#
#                                              endereço         bairro  cep  \
# 16  Av. Francisco Mesquita N-1000 - Loja Âncora "C...  Vila Prudente  NaN
# 17     Estrada do Campo Limpo, 459 - loja âncora A-01      Vila Prel  NaN
# 18                 Av. Ibirapuera, 3103 - lojas 4 e 5   Indianópolis  NaN
# 19               Av. Interlagos, 2255 - Loja "Arco A"   Campo Grande  NaN
# 20           Avenida Giovanni Gronchi, 5819 - LUC 001   Vila Andrade  NaN
#
#    tipo_de_material horario_seg_sex horario_sab_dom tipo
# 16  Lixo eletrônico             NaN             NaN  NaN
# 17  Lixo eletrônico             NaN             NaN  NaN
# 18  Lixo eletrônico             NaN             NaN  NaN
# 19  Lixo eletrônico             NaN             NaN  NaN
# 20  Lixo eletrônico             NaN             NaN  NaN

# %%
dados_patricia['cep'] = dados_patricia['cep'].fillna('00000-000')
dados_patricia[dados_patricia['cep'].isna()]
# Out:
# Empty DataFrame
# Columns: [estado, cidade, local, endereço, bairro, cep, tipo_de_material, horario_seg_sex, horario_sab_dom, tipo]
# Index: []

# %%
dados_patricia[dados_patricia.duplicated(keep=False)]
# Out:
#     estado          cidade          local  \
# 644     MG  Belo Horizonte       Heineken
# 653     MG  Belo Horizonte       Heineken
# 712     PE          Recife  Não informado
# 715     PE          Recife  Não informado
# 725     RJ  Rio de Janeiro  Não informado
# 730     RJ  Rio de Janeiro  Não informado
# 758     SC        São José  Não informado
# 760     SC        São José  Não informado
# 762     SC        São José  Não informado
# 763     SC        São José  Não informado
#
#                                               endereço         bairro  \
# 644   Avenida Fleming, 650, Ouro Preto, Belo Horizonte     Ouro Preto
# 653   Avenida Fleming, 650, Ouro Preto, Belo Horizonte     Ouro Preto
# 712  Avenida Engenheiro Domingos Ferreira, 1950\r\n...  Não informado
# 715  Avenida Engenheiro Domingos Ferreira, 1950\r\n...  Não informado
# 725  Avenida Mem de Sá, 81\r\nCentro, Rio de Janeir...  Não informado
# 730  Avenida Mem de Sá, 81\r\nCentro, Rio de Janeir...  Não informado
# 758  Rua Doutor Constâncio Krummel, 2183\r\nPraia C...  Não informado
# 760  Rua Antônio Jovita Duarte, 87\r\nForquilhas, S...  Não informado
# 762  Rua Antônio Jovita Duarte, 87\r\nForquilhas, S...  Não informado
# 763  Rua Doutor Constâncio Krummel, 2183\r\nPraia C...  Não informado
#
#            cep   tipo_de_material horario_seg_sex horario_sab_dom      tipo
# 644  31310-490  Garrafas de vidro         10 - 22         10 - 22  Heineken
# 653  31310-490  Garrafas de vidro         10 - 22         10 - 22  Heineken
# 712  00000-000  Garrafas de vidro         10 - 22         10 - 22  Heineken
# 715  00000-000  Garrafas de vidro         10 - 22         10 - 22  Heineken
# 725  00000-000  Garrafas de vidro         10 - 22         10 - 22  Heineken
# 730  00000-000  Garrafas de vidro         10 - 22         10 - 22  Heineken
# 758  00000-000  Garrafas de vidro         10 - 22         10 - 22  Heineken
# 760  00000-000  Garrafas de vidro         10 - 22         10 - 22  Heineken
# 762  00000-000  Garrafas de vidro         10 - 22         10 - 22  Heineken
# 763  00000-000  Garrafas de vidro         10 - 22         10 - 22  Heineken

# %%
dados_patricia = dados_patricia.drop_duplicates()
dados_patricia.duplicated().sum()
# Out:
# 0

# %%
dados_patricia['tipo'].value_counts()
# Out:
# tipo
# Heineken                        193
# Green Eletron                    79
# Boticário                        78
# Prefeitura de Belo Horizonte     58
# Exército da Salvação             57
# Três Corações                    44
# Name: count, dtype: int64

# %%
dados_patricia['tipo_de_material'].value_counts()
# Out:
# tipo_de_material
# Garrafas de vidro                                             193
# Cápsulas de café                                              158
# Lixo eletrônico                                               157
# Roupas                                                        110
# Embalagens de cosméticos, seja de plástico, vidro ou papel     78
# Roupas, brinquedos, calçados e outros pequenos objetos.        57
# Instrumentos de escrita                                        34
# Vidro                                                          21
# Vidro, plástico, metal e papel                                 18
# Vidro, papel, metal e plástico                                 16
# Plástico, metal e papel                                         3
# Papel, plástico, vidro e metal                                  2
# Name: count, dtype: int64

# %%
substituicoes_material = {
    'Vidro, plástico, metal e papel': 'Coleta seletiva',
    'Vidro, papel, metal e plástico': 'Coleta seletiva',
    'Plástico, metal e papel': 'Coleta seletiva',
    'Papel, plástico, vidro e metal': 'Coleta seletiva',
    'Embalagens de cosméticos, seja de plástico, vidro ou papel': 'Embalagens de cosméticos',
    'Garrafas de vidro':'Vidro',
    'Lixo eletrônico':'Eletrônicos'}

dados_patricia['tipo_de_material'] = dados_patricia['tipo_de_material'].replace(substituicoes_material)
dados_patricia['tipo_de_material'].unique()
# Out:
# array(['Cápsulas de café', 'Coleta seletiva', 'Eletrônicos', 'Roupas',
#        'Vidro', 'Instrumentos de escrita',
#        'Roupas, brinquedos, calçados e outros pequenos objetos.',
#        'Embalagens de cosméticos'], dtype=object)

# %%
dados_patricia['horario_seg_sex'].value_counts()
# Out:
# horario_seg_sex
# 10 - 22          238
# 07:00 -18:00      79
# 08:00 - 18:00     58
# 07:00 - 2200      57
# 07:00 - 22:00     33
# Name: count, dtype: int64

# %%
dados_patricia['horario_seg_sex'].isna().sum()
# Out:
# 382

# %%
substituicoes_horario_seg_sex = {
    '10 - 22': '10h-22h',
    '07:00 -18:00': '7h-18h',
    '08:00 - 18:00': '8h-18h',
    '07:00 - 2200': '7h-22h',
    '07:00 - 22:00': '7h-22h'}

dados_patricia['horario_seg_sex'] = dados_patricia['horario_seg_sex'].replace(substituicoes_horario_seg_sex)
dados_patricia['horario_seg_sex'] = dados_patricia['horario_seg_sex'].fillna('Não disponível')

dados_patricia['horario_seg_sex'].unique()
# Out:
# array(['Não disponível', '7h-22h', '7h-18h', '10h-22h', '8h-18h'],
#       dtype=object)

# %%
dados_patricia['horario_sab_dom'].value_counts()
# Out:
# horario_sab_dom
# 10 - 22           238
# 07:00 -14:00       79
# 08:00 - 12:00      58
# 09:-00 - 17:00     57
# 07:00 - 22:00      33
# Name: count, dtype: int64

# %%
dados_patricia['horario_sab_dom'].isna().sum()
# Out:
# 382

# %%
substituicoes_horario_sab_dom = {
    '10 - 22': '10h-22h',
    '07:00 -14:00': '7h-14h',
    '08:00 - 12:00': '8h-12h',
    '09:-00 - 17:00': '9h-17h',
    '07:00 - 22:00': '7h-22h'}

dados_patricia['horario_sab_dom'] = dados_patricia['horario_sab_dom'].replace(substituicoes_horario_sab_dom)
dados_patricia['horario_sab_dom'] = dados_patricia['horario_sab_dom'].fillna('Não disponível')

dados_patricia['horario_sab_dom'].unique()
# Out:
# array(['Não disponível', '7h-22h', '7h-14h', '9h-17h', '10h-22h',
#        '8h-12h'], dtype=object)

# %%
dados_patricia['tipo'].isna().sum()
# Out:
# 338

# %%
dados_patricia['tipo'] = dados_patricia['tipo'].fillna('Não informado')
dados_patricia['tipo'].unique()
# Out:
# array(['Três Corações', 'Não informado', 'Heineken', 'Green Eletron',
#        'Exército da Salvação', 'Boticário',
#        'Prefeitura de Belo Horizonte'], dtype=object)

# %% [markdown]
# # Juntando datasets

# %% [markdown]
# Com o pré-processamento feito, agora vou juntar os datasets.

# %%
dataset_final = pd.concat([dados_patricia, dados_luiz, dados_gabriel], ignore_index=True)
dataset_final
# Out:
#      estado      cidade                        local  \
# 0        SP   São Paulo               Hirota - Mooca
# 1        SP   São Paulo               Super Saudável
# 2        SP   São Paulo              COOP Industrial
# 3        SP   São Paulo          Hirota - Campo Belo
# 4        SP   São Paulo  Emporium São Paulo - Jurema
# ...     ...         ...                          ...
# 3012     SP  Piracicaba                    Drogaraia
# 3013     SP  Piracicaba                    Drogaraia
# 3014     SP  Piracicaba                    Drogaraia
# 3015     SP  Piracicaba                    Drogaraia
# 3016     SP  Piracicaba                    Drogaraia
#
#                                   endereço             bairro        cep  \
# 0                        Rua Teresina, 319      Vila Bertioga  03185-010
# 1                 Avenida São Gualter, 931  Alto de Pinheiros  05455-001
# 2                 Avenida Industrial, 2001          Campestre  09080-511
# 3                Rua Vieira de Morais, 263         Campo Belo  04617-010
# 4                      Avenida Jurema, 271       Indianópolis  04087-000
# ...                                    ...                ...        ...
# 3012                     Rua Corcovado, 71       Jardim Sonia  00000-000
# 3013  Rua Governador Pedro De Toledo, 1244             Centro  00000-000
# 3014           Avenida Dois Córregos, 1610      Piracicamirim  00000-000
# 3015    Avenida Armando Cesare Dedini, 405   Norte Piracicaba  00000-000
# 3016     Avenida Madre Maria Teodora, 1062            Jaraguá  00000-000
#
#       tipo_de_material horario_seg_sex horario_sab_dom           tipo
# 0     Cápsulas de café  Não disponível  Não disponível  Três Corações
# 1     Cápsulas de café  Não disponível  Não disponível  Não informado
# 2     Cápsulas de café  Não disponível  Não disponível  Não informado
# 3     Cápsulas de café  Não disponível  Não disponível  Não informado
# 4     Cápsulas de café  Não disponível  Não disponível  Não informado
# ...                ...             ...             ...            ...
# 3012      Medicamentos          7h-19h          7h-19h        privado
# 3013      Medicamentos          7h-19h          7h-19h        privado
# 3014      Medicamentos          7h-19h          7h-19h        privado
# 3015      Medicamentos          7h-19h          7h-19h        privado
# 3016      Medicamentos          7h-19h          7h-19h        privado
#
# [3017 rows x 10 columns]

# %%
problemas_dataset_final = verificar_dados(dataset_final, "dataset final")
print(problemas_dataset_final)
# Out:
# Existem 0 valores ausentes em dataset final
# Existem 0 valores duplicados em dataset final

# %%
dataset_final.isna().sum()
# Out:
# estado              0
# cidade              0
# local               0
# endereço            0
# bairro              0
# cep                 0
# tipo_de_material    0
# horario_seg_sex     0
# horario_sab_dom     0
# tipo                0
# dtype: int64

# %% [markdown]
# Agora precisamos definir o que fazer com as colunas de "tipo"

# %%
dataset_final['tipo'].value_counts()
# Out:
# tipo
# Drogasil                        675
# Carrefour                       589
# Não informado                   338
# privado                         239
# Heineken                        193
# Ecoponto                        177
# PEV                             157
# ecoponto                        129
# Pão de Açúcar                    95
# Green Eletron                    79
# Boticário                        78
# Empresa                          77
# Prefeitura de Belo Horizonte     58
# Exército da Salvação             57
# Três Corações                    44
# Cooperativa                      29
# Supermercado                      2
# Universidade                      1
# Name: count, dtype: int64

# %% [markdown]
# Vou realizar alguns agrupamentos renomeando algumas valores.

# %%
substituicoes_tipo = {
    'Drogasil': 'Drogaria',
    'privado': 'Drogaria',
    'Carrefour': 'Supermercado',
    'Pão de Açúcar': 'Supermercado',
    'Empresa': 'Empresa privada',
    'Green Eletron': 'Supermercado',
    'Heineken': 'Empresa privada',
    'Boticário': 'Empresa privada',
    'Três Corações': 'Empresa privada',
    'Prefeitura de Belo Horizonte': 'Ecoponto',
    'Exército da Salvação': 'PEV',
    'ecoponto': 'Ecoponto',
    'Não informado': 'Empresa privada',
    'Cooperativa': 'Empresa privada',
    'Universidade': 'PEV'}

dataset_final['tipo'] = dataset_final['tipo'].replace(substituicoes_tipo)
dataset_final['tipo'].value_counts()
# Out:
# tipo
# Drogaria           914
# Supermercado       765
# Empresa privada    759
# Ecoponto           364
# PEV                215
# Name: count, dtype: int64

# %%
dataset_final['tipo_de_material'].value_counts()
# Out:
# tipo_de_material
# Medicamentos                                                           914
# Eletrônicos                                                            640
# Vidro                                                                  214
# Cápsulas de café                                                       158
#  Coleta seletiva, Obras e materiais, Líquidos, Eletrônicos,Borracha    158
# Coleta seletiva                                                        158
# Coleta seletiva, Liquidos                                              111
# Roupas                                                                 110
# Coleta seletiva, Líquidos                                               95
# Embalagens de cosméticos                                                78
# Liquídos                                                                75
# Roupas, brinquedos, calçados e outros pequenos objetos.                 57
# Coleta Seletiva, Obras E Materiais                                      48
# Coleta seletiva                                                         45
# Instrumentos de escrita                                                 34
# Coleta Seletiva, Obras E Materiais, Líquidos, Borracha                  33
# Coleta Seletiva, Obras E Materiais, Eletrônicos, Líquidos, Borracha     15
# Coleta Seletiva, Obras E Materiais, Borracha E Eletrônicos              14
# Coleta Seletiva, Obras E Materiais, Eletrônicos                         12
# Eletrônicos,Medicamentos                                                10
# Coleta Seletiva, Obras e Materiais, Eletrônicos, Borracha               10
# Obras e materiais                                                        8
# Coleta Seletiva, Eletrônicos, Líquidos, Obras E Materiais                5
#  Coleta seletiva, Obras e materiais, Líquidos, Borracha                  5
# Coleta Seletiva                                                          4
# Coleta Seletiva, Obras e Materiais, Eletrônicos                          3
# Borracha                                                                 2
# Coleta seletiva,Eletrônicos                                              1
# Name: count, dtype: int64

# %%
substituicoes_tipo_de_materiais_final = {
    ' Coleta seletiva, Obras e materiais, Líquidos, Eletrônicos,Borracha': 'Coleta seletiva, obras e materiais, líquidos, eletrônicos, borracha',
    'Coleta seletiva, Liquidos': 'Coleta seletiva, líquidos',
    'Coleta seletiva, Líquidos': 'Coleta seletiva, líquidos',
    'Liquídos': 'Líquidos',
    'Coleta Seletiva, Obras E Materiais': 'Coleta seletiva, obras e materiais',
    'Coleta Seletiva, Obras E Materiais, Líquidos, Borracha': 'Coleta seletiva, obras e materiais, líquidos, borracha',
    'Coleta Seletiva, Obras E Materiais, Eletrônicos, Líquidos, Borracha' : 'Coleta seletiva, obras e materiais, eletrônicos, líquidos, borracha',
    'Coleta Seletiva, Obras E Materiais, Borracha E Eletrônicos': 'Coleta seletiva, obras e materiais, eletrônicos, borracha',
    'Coleta Seletiva, Obras E Materiais, Eletrônicos': 'Coleta seletiva, obras e materiais, eletrônicos',
    'Eletrônicos,Medicamentos': 'Eletrônicos, medicamentos',
    'Coleta Seletiva, Obras e Materiais, Eletrônicos, Borracha': 'Coleta seletiva, obras e materiais, eletrônicos, borracha',
    'Coleta Seletiva, Eletrônicos, Líquidos, Obras E Materiais': 'Coleta seletiva, obras e materiais, eletrônicos, líquidos',
    ' Coleta seletiva, Obras e materiais, Líquidos, Borracha': 'Coleta seletiva, obras e materiais, líquidos, borracha',
    'Coleta Seletiva': 'Coleta seletiva',
    'Coleta Seletiva, Obras e Materiais, Eletrônicos': 'Coleta seletiva, obras e materiais, eletrônicos',
    'Coleta seletiva,Eletrônicos': 'Coleta seletiva, eletrônicos',
    'Coleta seletiva ': 'Coleta seletiva',
    'Roupas, brinquedos, calçados e outros pequenos objetos.': 'Roupas'}

dataset_final['tipo_de_material'] = dataset_final['tipo_de_material'].replace(substituicoes_tipo_de_materiais_final)
dataset_final['tipo_de_material'].value_counts()
# Out:
# tipo_de_material
# Medicamentos                                                           914
# Eletrônicos                                                            640
# Vidro                                                                  214
# Coleta seletiva                                                        207
# Coleta seletiva, líquidos                                              206
# Roupas                                                                 167
# Cápsulas de café                                                       158
# Coleta seletiva, obras e materiais, líquidos, eletrônicos, borracha    158
# Embalagens de cosméticos                                                78
# Líquidos                                                                75
# Coleta seletiva, obras e materiais                                      48
# Coleta seletiva, obras e materiais, líquidos, borracha                  38
# Instrumentos de escrita                                                 34
# Coleta seletiva, obras e materiais, eletrônicos, borracha               24
# Coleta seletiva, obras e materiais, eletrônicos                         15
# Coleta seletiva, obras e materiais, eletrônicos, líquidos, borracha     15
# Eletrônicos, medicamentos                                               10
# Obras e materiais                                                        8
# Coleta seletiva, obras e materiais, eletrônicos, líquidos                5
# Borracha                                                                 2
# Coleta seletiva, eletrônicos                                             1
# Name: count, dtype: int64

# %%
dataset_final['bairro'].value_counts()
# Out:
# bairro
# Centro           190
# Não informado    158
# Pinheiros         35
# Bela Vista        30
# Vila Mariana      28
#                 ...
# R Pequeno          1
# Jd L Moreira       1
# Monção             1
# Rochdale           1
# Jaraguá            1
# Name: count, Length: 1534, dtype: int64

# %% [markdown]
# Vou remover todos Bairros catalogados como não informados

# %%
dataset_final = dataset_final[dataset_final['bairro'] != 'Não informado']
dataset_final['bairro'].value_counts()
# Out:
# bairro
# Centro          190
# Pinheiros        35
# Bela Vista       30
# Vila Mariana     28
# Santo Amaro      24
#                ...
# R Pequeno         1
# Jd L Moreira      1
# Monção            1
# Rochdale          1
# Jaraguá           1
# Name: count, Length: 1533, dtype: int64

# %% [markdown]
# Agora vou mudar o local de todos pontos de coleta que coletam instrumentos de escrita.

# %%
local_change = dataset_final['tipo_de_material'] == 'Instrumentos de escrita'
dataset_final.loc[local_change, 'local'] = 'Ponto Faber Castell'

# %%
dataset_final[dataset_final['tipo_de_material'] == 'Instrumentos de escrita']
# Out:
#     estado        cidade                local  \
# 486     SP   Hortolândia  Ponto Faber Castell
# 487     SP         Tietê  Ponto Faber Castell
# 488     SP       Limeira  Ponto Faber Castell
# 489     SP       Limeira  Ponto Faber Castell
# 490     SP        Juquiá  Ponto Faber Castell
# 491     SP  Itapetininga  Ponto Faber Castell
# 492     SP      Registro  Ponto Faber Castell
# 493     SP   Barra Velha  Ponto Faber Castell
#
#                                               endereço            bairro  \
# 486  Hortolândia, Av.Thereza Ana Cecon Breda, 1896 ...   Jardim Arpoador
# 487                 Tietê, Avenida Onze de Agosto, 130           Diadema
# 488                 LIMEIRA, Rua Alfredo Mesanelli 110           Diadema
# 489  LIMEIRA, RUA ANTONIO JORGE LOUREIRO, 303 JD OU...            Macedo
# 490       Juquiá, Rua Major Martins Coelho, 439 Centro           Gopoúva
# 491           Itapetininga, R. Dom Joaquim, 495 Centro     Vila Zeferina
# 492  Registro, AVENIDA DEPUTADO ULISSES GUIMARAES N...  Jardim Gagliardi
# 493  Barra Velha, Rua Marino Atanásio Pinheiro, 51 ...            Centro
#
#            cep         tipo_de_material horario_seg_sex horario_sab_dom  \
# 486  00000-000  Instrumentos de escrita  Não disponível  Não disponível
# 487  00000-000  Instrumentos de escrita  Não disponível  Não disponível
# 488  00000-000  Instrumentos de escrita  Não disponível  Não disponível
# 489  00000-000  Instrumentos de escrita  Não disponível  Não disponível
# 490  00000-000  Instrumentos de escrita  Não disponível  Não disponível
# 491  00000-000  Instrumentos de escrita  Não disponível  Não disponível
# 492  00000-000  Instrumentos de escrita  Não disponível  Não disponível
# 493  00000-000  Instrumentos de escrita  Não disponível  Não disponível
#
#                 tipo
# 486  Empresa privada
# 487  Empresa privada
# 488  Empresa privada
# 489  Empresa privada
# 490  Empresa privada
# 491  Empresa privada
# 492  Empresa privada
# 493  Empresa privada

# %% [markdown]
# Vou remover a coluna CEP.

# %%
dataset_final = dataset_final.drop(columns=['cep'])
dataset_final.head()
# Out:
#   estado     cidade                        local                   endereço  \
# 0     SP  São Paulo               Hirota - Mooca          Rua Teresina, 319
# 1     SP  São Paulo               Super Saudável   Avenida São Gualter, 931
# 2     SP  São Paulo              COOP Industrial   Avenida Industrial, 2001
# 3     SP  São Paulo          Hirota - Campo Belo  Rua Vieira de Morais, 263
# 4     SP  São Paulo  Emporium São Paulo - Jurema        Avenida Jurema, 271
#
#               bairro  tipo_de_material horario_seg_sex horario_sab_dom  \
# 0      Vila Bertioga  Cápsulas de café  Não disponível  Não disponível
# 1  Alto de Pinheiros  Cápsulas de café  Não disponível  Não disponível
# 2          Campestre  Cápsulas de café  Não disponível  Não disponível
# 3         Campo Belo  Cápsulas de café  Não disponível  Não disponível
# 4       Indianópolis  Cápsulas de café  Não disponível  Não disponível
#
#               tipo
# 0  Empresa privada
# 1  Empresa privada
# 2  Empresa privada
# 3  Empresa privada
# 4  Empresa privada

# %% [markdown]
# Acoplamentos de datasets feitos. Partimos agora para algumas visualizações.

# %%
dataset_final
# Out:
#      estado      cidade                        local  \
# 0        SP   São Paulo               Hirota - Mooca
# 1        SP   São Paulo               Super Saudável
# 2        SP   São Paulo              COOP Industrial
# 3        SP   São Paulo          Hirota - Campo Belo
# 4        SP   São Paulo  Emporium São Paulo - Jurema
# ...     ...         ...                          ...
# 3012     SP  Piracicaba                    Drogaraia
# 3013     SP  Piracicaba                    Drogaraia
# 3014     SP  Piracicaba                    Drogaraia
# 3015     SP  Piracicaba                    Drogaraia
# 3016     SP  Piracicaba                    Drogaraia
#
#                                   endereço             bairro  \
# 0                        Rua Teresina, 319      Vila Bertioga
# 1                 Avenida São Gualter, 931  Alto de Pinheiros
# 2                 Avenida Industrial, 2001          Campestre
# 3                Rua Vieira de Morais, 263         Campo Belo
# 4                      Avenida Jurema, 271       Indianópolis
# ...                                    ...                ...
# 3012                     Rua Corcovado, 71       Jardim Sonia
# 3013  Rua Governador Pedro De Toledo, 1244             Centro
# 3014           Avenida Dois Córregos, 1610      Piracicamirim
# 3015    Avenida Armando Cesare Dedini, 405   Norte Piracicaba
# 3016     Avenida Madre Maria Teodora, 1062            Jaraguá
#
#       tipo_de_material horario_seg_sex horario_sab_dom             tipo
# 0     Cápsulas de café  Não disponível  Não disponível  Empresa privada
# 1     Cápsulas de café  Não disponível  Não disponível  Empresa privada
# 2     Cápsulas de café  Não disponível  Não disponível  Empresa privada
# 3     Cápsulas de café  Não disponível  Não disponível  Empresa privada
# 4     Cápsulas de café  Não disponível  Não disponível  Empresa privada
# ...                ...             ...             ...              ...
# 3012      Medicamentos          7h-19h          7h-19h         Drogaria
# 3013      Medicamentos          7h-19h          7h-19h         Drogaria
# 3014      Medicamentos          7h-19h          7h-19h         Drogaria
# 3015      Medicamentos          7h-19h          7h-19h         Drogaria
# 3016      Medicamentos          7h-19h          7h-19h         Drogaria
#
# [2859 rows x 9 columns]

# %% [markdown]
# # Visualizando dados

# %%
estado_counts = dataset_final['estado'].value_counts()

top_5_estados = estado_counts.head(5)
other_estados_count = estado_counts[5:].sum()

top_5_estados['Outros'] = other_estados_count

labels = [f'{state}' for state in top_5_estados.index]

plt.figure(figsize=(12, 6), dpi = 300)
plt.pie(
    top_5_estados,
    labels=labels,
    startangle=140,
    labeldistance=1.05,  
    wedgeprops={'edgecolor': 'black'})
plt.title('Distribuição de Informações Coletadas por Estado')
plt.axis('equal') 
plt.show()

# %%
material_counts = dataset_final['tipo_de_material'].value_counts()

plt.figure(figsize=(14, 8), dpi = 300)
bars = plt.bar(material_counts.index, material_counts, color=plt.cm.Paired(range(len(material_counts))), edgecolor='black')

plt.title('Distribuição dos Tipos de Material Coletados')
plt.xlabel('Tipo de Material')
plt.ylabel('Frequência')

plt.xticks(rotation=45, ha='right')

plt.tight_layout() 
plt.show()

# %%
tipo_counts = dataset_final['tipo'].value_counts()

plt.figure(figsize=(10, 6), dpi = 500)
bars = plt.bar(tipo_counts.index, tipo_counts, color=plt.cm.Paired(range(len(tipo_counts))), edgecolor='black')

plt.title('Tipos de filiação dos pontos de coleta')
plt.xlabel('Tipo')
plt.ylabel('Frequência')

plt.xticks(rotation=45, ha='right')

plt.tight_layout() 
plt.show()
